# %%
import datetime
import math
import re
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
from sklearn.utils import check_array
from sklearn.preprocessing import LabelBinarizer, OrdinalEncoder, KBinsDiscretizer, OneHotEncoder, LabelEncoder, FunctionTransformer, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, train_test_split, cross_validate
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
import lightgbm as lgbm

# %% [markdown]
# #### Utility

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    """Returns MAPE (%) for prediction"""
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    y_true = y_true.reshape(-1, 1)
    y_pred = y_pred.reshape(-1, 1)
    return np.abs(np.mean(np.abs((y_true - y_pred) / y_true)))

# %%
def log_preprocessing(array: np.array):
    return array + 1

# %%
def inverse_log_preprocessing(array: np.array):
    return array - 1

# %%
def inverse_np_log(array: np.array):
    def inverse_log(x):
        return math.e ** x
    func = np.vectorize(inverse_log)
    result = func(array)
    return result

# %% [markdown]
# #### Utility constants

# %%
DATE_AVG = pd.to_datetime('2015-06-01')
RANDOM_STATE = 23

# %% [markdown]
# #### Load data

# %%
calendar = pd.read_csv("calendar.csv")
reviews = pd.read_csv("reviews.csv")
sample_submission = pd.read_csv("sample_submission.csv")
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
calendar
# Out:
#           listing_id        date available
# 0               9554  2019-08-18         t
# 1              97446  2019-11-04         f
# 2              97446  2019-11-03         f
# 3              97446  2019-11-02         f
# 4              97446  2019-11-01         f
# ...              ...         ...       ...
# 27307470    27182471  2018-11-09         f
# 27307471    27182471  2018-11-08         f
# 27307472    27182471  2018-11-07         f
# 27307473    27182471  2018-11-06         f
# 27307474    27182471  2018-11-05         f
#
# [27307475 rows x 3 columns]

# %%
reviews
# Out:
#          listing_id         id        date  reviewer_id    reviewer_name  \
# 0              9554    1184025  2012-04-26      1809049             Hana
# 1              9554    1206322  2012-04-30      2237488            Rishi
# 2              9554    1258541  2012-05-10      2150467            Panee
# 3              9554    1405284  2012-06-03      1864672  Simone Cristina
# 4              9554    1475969  2012-06-13      2438453           Sondra
# ...             ...        ...         ...          ...              ...
# 1137319    29735949  344807582  2018-11-04     27552372           Declan
# 1137320    29736900  344387254  2018-11-03    109537206           Shazia
# 1137321    29756033  344498174  2018-11-03     26000990           Andrea
# 1137322    29775194  345574439  2018-11-05     34546792           Robert
# 1137323    29793575  345445323  2018-11-05    111603523             Alex
#
#                                                   comments
# 0        I  stayed  in London for a month to study, exp...
# 1        My bnb request was very last minute and i was ...
# 2        First time as airbnb!First time to London! I c...
# 3        A wonderful experience! The house is very well...
# 4        We are so grateful that we trusted our intuiti...
# ...                                                    ...
# 1137319  Clean, spacious, stylish apartment close to ev...
# 1137320  spotless clean flat with amazing view. the hos...
# 1137321  The host canceled this reservation 55 days bef...
# 1137322  The host canceled this reservation 45 days bef...
# 1137323  The host canceled this reservation 53 days bef...
#
# [1137324 rows x 6 columns]

# %%
train_data
# Out:
#              id                                               name  \
# 0        127860  Double bedroom in cottage Twickenham (sleeps 1-2)
# 1        325809                Big House for Olympics sleeps 6 to8
# 2        429045                     The Old Coach House (Olympics)
# 3        473637                 Brand New contemporary mews house
# 4        533943                 LUXURY APT. NEAR BUCKINGHAM PALACE
# ...         ...                                                ...
# 51810  29797787           Bright, modern flat in Wimbledon Village
# 51811  29797809    Luxury 2 Bdrm by The Shard Panoramic city views
# 51812  29797854                         Spare bed, close to london
# 51813  29797899                              Greenlane Guest House
# 51814  29798497    Newly Refurbished Two Bed/ Two Bath Flat Zone 2
#
#                                                  summary  \
# 0      One gorgeous, light-filled double bedroom (sle...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      “The area around Westminster Cathedral has lon...
# ...                                                  ...
# 51810  Recently refurbished open plan flat set in a q...
# 51811  Luxury 2 Bdrm by Shard with amazing panoramic ...
# 51812                                                NaN
# 51813  Property close by Heathrow Airport, A Large do...
# 51814                                                NaN
#
#                                                    space  \
# 0      A beautiful, light-filled double bedroom is ou...
# 1      A beautiful, modern, art-filled and clean 4 st...
# 2      Fabulous, recently refurbished original Victor...
# 3      Stunning contemporary mews available for let o...
# 4      This stunning, spacious, 4 bedroom, top floor ...
# ...                                                  ...
# 51810  Light, bright first floor flat with a brand ne...
# 51811  A modern luxury 2 bedroom apartment by The Sha...
# 51812                                                NaN
# 51813  Large open plan living area, with a spacious s...
# 51814                                                NaN
#
#                                              description experiences_offered  \
# 0      One gorgeous, light-filled double bedroom (sle...                none
# 1      A beautiful, modern, art-filled and clean 4 st...                none
# 2      Fabulous, recently refurbished original Victor...                none
# 3      Stunning contemporary mews available for let o...                none
# 4      “The area around Westminster Cathedral has lon...              family
# ...                                                  ...                 ...
# 51810  Recently refurbished open plan flat set in a q...                none
# 51811  Luxury 2 Bdrm by Shard with amazing panoramic ...                none
# 51812                                                NaN                none
# 51813  Property close by Heathrow Airport, A Large do...                none
# 51814                                                NaN                none
#
#                                    neighborhood_overview  \
# 0      Very, very safe area, great transport links an...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      The proximity of all of London's main attracti...
# ...                                                  ...
# 51810                                                NaN
# 51811                                                NaN
# 51812                                                NaN
# 51813  A lot of greenery around this property, great ...
# 51814                                                NaN
#
#                                                   notes  \
# 0                          We have a super-gorgeous cat
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 51810                                               NaN
# 51811                                               NaN
# 51812                                               NaN
# 51813  Full internet service provided, Netflix and WiFi
# 51814                                               NaN
#
#                                                  transit  \
# 0      Twickenham Rugby Stadium is 15 mins walk Water...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Only 5 minutes walk to Victoria Station, the m...
# ...                                                  ...
# 51810                                                NaN
# 51811                                                NaN
# 51812                                                NaN
# 51813  Best way to travel is via a bus, easy to hop o...
# 51814                                                NaN
#
#                                                   access  ... square_feet  \
# 0      You'll have full use of the cottage, two recep...  ...         NaN
# 1                                                    NaN  ...      1400.0
# 2                                                    NaN  ...      1800.0
# 3                                                    NaN  ...      2100.0
# 4                                                    NaN  ...      2220.0
# ...                                                  ...  ...         ...
# 51810                                                NaN  ...         NaN
# 51811                   Sole use of the entire apartment  ...         NaN
# 51812                                                NaN  ...         NaN
# 51813                Private area for guests- not shared  ...         NaN
# 51814                                                NaN  ...         NaN
#
#       security_deposit  cleaning_fee guests_included extra_people  \
# 0                300.0          10.0               1         10.0
# 1                771.0           NaN               1          0.0
# 2                600.0           NaN               1          0.0
# 3                300.0         100.0               7        100.0
# 4               2505.0         180.0               1          0.0
# ...                ...           ...             ...          ...
# 51810              NaN           NaN               1          0.0
# 51811           3856.0          75.0               2         10.0
# 51812              NaN           NaN               1          0.0
# 51813              NaN           NaN               1          0.0
# 51814              NaN          30.0               1          0.0
#
#       minimum_nights          cancellation_policy  \
# 0                  2  strict_14_with_grace_period
# 1                 14  strict_14_with_grace_period
# 2                 14  strict_14_with_grace_period
# 3                 14  strict_14_with_grace_period
# 4                 14  strict_14_with_grace_period
# ...              ...                          ...
# 51810              2                     flexible
# 51811              3  strict_14_with_grace_period
# 51812              1                     flexible
# 51813              1                     flexible
# 51814              2                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification   price
# 0                                 f                                f  1000.0
# 1                                 f                                f   771.0
# 2                                 f                                f  1500.0
# 3                                 f                                f  2000.0
# 4                                 f                                t   901.0
# ...                             ...                              ...     ...
# 51810                             f                                f    68.0
# 51811                             f                                f   349.0
# 51812                             f                                f   100.0
# 51813                             f                                f    69.0
# 51814                             f                                f   100.0
#
# [51815 rows x 43 columns]

# %%
sample_submission
# Out:
#              id  price
# 0          9554      0
# 1         11076      0
# 2         13913      0
# 3         17402      0
# 4         24328      0
# ...         ...    ...
# 22995  13559787      0
# 22996  13561162      0
# 22997  13561394      0
# 22998  13561787      0
# 22999  13561861      0
#
# [23000 rows x 2 columns]

# %%
test_data
# Out:
#              id                                               name  \
# 0          9554                 Cozy, 3 minutes to Piccadilly Line
# 1         11076                                      The Sanctuary
# 2         13913                Holiday London DB Room Let-on going
# 3         17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1
# 4         24328                Battersea 2 bedroom house & parking
# ...         ...                                                ...
# 22995  13559787  Spacious, Cool Clapton Apt in the Buzz of Hackney
# 22996  13561162  Nice Apartment; Great Portland St, Regents Pk,...
# 22997  13561394                 Beautiful 3 bed house in Battersea
# 22998  13561787     A charming family house close to tube station.
# 22999  13561861         Double room with a view - and car parking!
#
#                                                  summary  \
# 0      PLEASE CONTACT ME BEFORE BOOKING Homely apartm...
# 1      The room has a double bed and a single foldawa...
# 2      My bright double bedroom with a large window h...
# 3      Open from June 2018 after a 3-year break, we a...
# 4      Artist house, high ceiling bedrooms, private p...
# ...                                                  ...
# 22995  Welcome to my oasis in the heart of Hackney! T...
# 22996  My Newly Styled Apartment is In a great Locati...
# 22997  Our house is close to Battersea Park (10 min w...
# 22998  Sole use of house with parking, just over 5 mi...
# 22999  My place is close to Epping Forest. You’ll lov...
#
#                                                    space  \
# 0      Hello people, This is a bright, comfortable ro...
# 1      This Listing is for The Sanctury The accommoda...
# 2      Hello Everyone, I'm offering my lovely double ...
# 3      Ready again from June 2018 for bookings after ...
# 4      - End of terrace two bedroom house close to So...
# ...                                                  ...
# 22995                                                NaN
# 22996  - Located At The Corner Of 'Robert Street & Al...
# 22997                                                NaN
# 22998                                                NaN
# 22999                                                NaN
#
#                                              description experiences_offered  \
# 0      PLEASE CONTACT ME BEFORE BOOKING Homely apartm...                none
# 1      The room has a double bed and a single foldawa...                none
# 2      My bright double bedroom with a large window h...            business
# 3      Open from June 2018 after a 3-year break, we a...                none
# 4      Artist house, high ceiling bedrooms, private p...              family
# ...                                                  ...                 ...
# 22995  Welcome to my oasis in the heart of Hackney! T...                none
# 22996  My Newly Styled Apartment is In a great Locati...                none
# 22997  Our house is close to Battersea Park (10 min w...                none
# 22998  Sole use of house with parking, just over 5 mi...                none
# 22999  My place is close to Epping Forest. You’ll lov...                none
#
#                                    neighborhood_overview  \
# 0                                    Details to follow..
# 1      Ealing Broadway, as short walk from our place ...
# 2      Finsbury Park is a friendly melting pot commun...
# 3      Location, location, location! You won't find b...
# 4      - Battersea is a quiet family area, easy acces...
# ...                                                  ...
# 22995                                                NaN
# 22996  Euston Great Portland Street Marylebone Camden...
# 22997                                                NaN
# 22998                                                NaN
# 22999                                                NaN
#
#                                                    notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2      For art lovers I can give guest my Tate Member...
# 3      This property has new flooring throughout. Gue...
# 4      - Please have a profile or tell us more about ...
# ...                                                  ...
# 22995                                                NaN
# 22996  Arrival Times Must Be Organised With Us.  Late...
# 22997                                                NaN
# 22998                                                NaN
# 22999                                                NaN
#
#                                                  transit  \
# 0                details to follow when i get a chance..
# 1      extemely good transport links to central londo...
# 2      The flat only a 10 minute walk to Finsbury Par...
# 3      You can walk to tourist London or take numerou...
# 4      - 5 mins walk to Battersea Park, 15 mins walk ...
# ...                                                  ...
# 22995                                                NaN
# 22996                                                NaN
# 22997                                                NaN
# 22998                                                NaN
# 22999                                                NaN
#
#                                                   access  ...  \
# 0      Kitchen, small dining / smoking room (if you s...  ...
# 1                      Huge family kitchen and good wifi  ...
# 2      Guest will have access to the self catering ki...  ...
# 3                Full use of whole independent apartment  ...
# 4      - there is a communal garden in our complex - ...  ...
# ...                                                  ...  ...
# 22995                                                NaN  ...
# 22996                                  Private Apartment  ...
# 22997                                                NaN  ...
# 22998                                                NaN  ...
# 22999                                                NaN  ...
#
#                                                amenities square_feet  \
# 0      {TV,Internet,Wifi,Kitchen,"Smoking allowed",Br...         NaN
# 1      {TV,"Cable TV",Internet,Wifi,Breakfast,"Pets l...         NaN
# 2      {TV,"Cable TV",Wifi,Kitchen,"Paid parking off ...       538.0
# 3      {TV,Wifi,Kitchen,"Paid parking off premises",E...         NaN
# 4      {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...      1001.0
# ...                                                  ...         ...
# 22995  {TV,Wifi,"Air conditioning",Kitchen,Breakfast,...         NaN
# 22996  {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...         NaN
# 22997  {TV,Wifi,Kitchen,"Free parking on premises","I...         NaN
# 22998  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...         NaN
# 22999  {Wifi,Kitchen,"Free parking on premises","Fami...         NaN
#
#        security_deposit cleaning_fee guests_included extra_people  \
# 0                   NaN          7.0               1         15.0
# 1                   NaN          NaN               2         35.0
# 2                 100.0         15.0               1         15.0
# 3                 350.0         65.0               4         10.0
# 4                 250.0         70.0               2         15.0
# ...                 ...          ...             ...          ...
# 22995             500.0         40.0               1          0.0
# 22996              99.0          0.0               2          0.0
# 22997              75.0         35.0               1          0.0
# 22998             250.0         40.0               1          0.0
# 22999             100.0          5.0               1          0.0
#
#       minimum_nights          cancellation_policy  \
# 0                  1  strict_14_with_grace_period
# 1                  2  strict_14_with_grace_period
# 2                  1                     moderate
# 3                  3  strict_14_with_grace_period
# 4                 90  strict_14_with_grace_period
# ...              ...                          ...
# 22995              3                     flexible
# 22996              1  strict_14_with_grace_period
# 22997              4                     flexible
# 22998              2  strict_14_with_grace_period
# 22999              1                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification
# 0                                 t                                f
# 1                                 f                                f
# 2                                 f                                f
# 3                                 f                                f
# 4                                 t                                t
# ...                             ...                              ...
# 22995                             f                                f
# 22996                             f                                f
# 22997                             f                                f
# 22998                             f                                f
# 22999                             f                                f
#
# [23000 rows x 42 columns]

# %% [markdown]
# ## EDA

# %%
profile = ProfileReport(train_data)
profile.to_file(output_file="train_data_profile_report.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=57.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…

# %%
train_data['price'].max()
# Out:
# 13700.0

# %%
log_scale_transformer = Pipeline(steps=[
    ('log_preprocessing', FunctionTransformer(log_preprocessing, validate=False)),
    ('log_transorm', FunctionTransformer(np.log, validate=False)),
    ('scaler', StandardScaler())
])
temp_X = np.asarray(train_data['price']).reshape(-1, 1)
temp_X = log_scale_transformer.fit_transform(temp_X)

# %% [markdown]
# Look at profile report

# %% [markdown]
# ## Preprocessing data

# %%
used_features = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 
                 'square_feet', 'security_deposit', 'cleaning_fee',
                 'guests_included', 'extra_people', 'minimum_nights', 'price']
used_features_test = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 
                 'square_feet', 'security_deposit', 'cleaning_fee',
                 'guests_included', 'extra_people', 'minimum_nights']

# %%
train_X = train_data.copy()[used_features]

# %%
test_X = test_data.copy()[used_features_test]
test_X
# Out:
#        accommodates  bathrooms  bedrooms  beds  square_feet  security_deposit  \
# 0                 2        NaN       1.0   1.0          NaN               NaN
# 1                 2        NaN       1.0   1.0          NaN               NaN
# 2                 2        1.0       1.0   1.0        538.0             100.0
# 3                 6        2.0       3.0   3.0          NaN             350.0
# 4                 4        1.5       2.0   2.0       1001.0             250.0
# ...             ...        ...       ...   ...          ...               ...
# 22995             2        1.0       1.0   1.0          NaN             500.0
# 22996             3        1.0       1.0   2.0          NaN              99.0
# 22997             6        1.5       3.0   3.0          NaN              75.0
# 22998             5        1.0       3.0   3.0          NaN             250.0
# 22999             2        1.0       1.0   1.0          NaN             100.0
#
#        cleaning_fee  guests_included  extra_people  minimum_nights
# 0               7.0                1          15.0               1
# 1               NaN                2          35.0               2
# 2              15.0                1          15.0               1
# 3              65.0                4          10.0               3
# 4              70.0                2          15.0              90
# ...             ...              ...           ...             ...
# 22995          40.0                1           0.0               3
# 22996           0.0                2           0.0               1
# 22997          35.0                1           0.0               4
# 22998          40.0                1           0.0               2
# 22999           5.0                1           0.0               1
#
# [23000 rows x 10 columns]

# %%
train_X
# Out:
#        accommodates  bathrooms  bedrooms  beds  square_feet  security_deposit  \
# 0                 2        1.0       1.0   1.0          NaN             300.0
# 1                 8        2.5       3.0   4.0       1400.0             771.0
# 2                 6        3.0       3.0   3.0       1800.0             600.0
# 3                 9        4.0       4.0   6.0       2100.0             300.0
# 4                 8        3.0       4.0   6.0       2220.0            2505.0
# ...             ...        ...       ...   ...          ...               ...
# 51810             2        1.0       2.0   1.0          NaN               NaN
# 51811             6        2.0       2.0   2.0          NaN            3856.0
# 51812             1        1.5       1.0   1.0          NaN               NaN
# 51813             2        1.0       1.0   4.0          NaN               NaN
# 51814             3        2.0       2.0   1.0          NaN               NaN
#
#        cleaning_fee  guests_included  extra_people  minimum_nights   price
# 0              10.0                1          10.0               2  1000.0
# 1               NaN                1           0.0              14   771.0
# 2               NaN                1           0.0              14  1500.0
# 3             100.0                7         100.0              14  2000.0
# 4             180.0                1           0.0              14   901.0
# ...             ...              ...           ...             ...     ...
# 51810           NaN                1           0.0               2    68.0
# 51811          75.0                2          10.0               3   349.0
# 51812           NaN                1           0.0               1   100.0
# 51813           NaN                1           0.0               1    69.0
# 51814          30.0                1           0.0               2   100.0
#
# [51815 rows x 11 columns]

# %%
used_features_new = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 
                 'square_feet', 'security_deposit', 'cleaning_fee',
                 'guests_included', 'extra_people', 'minimum_nights']

# %%
numerical_features = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 
                 'square_feet', 'security_deposit', 'cleaning_fee',
                 'guests_included', 'extra_people', 'minimum_nights']

# %% [markdown]
# ### Missing values

# %%
numerical_imputer = SimpleImputer(strategy='median')

# %%
train_X_price = np.asarray(train_X['price']).reshape(-1, 1)

# %%
train_X.drop(['price'], axis=1, inplace=True)

# %%
missing_preprocessor = ColumnTransformer(transformers=[
    ('numerical', numerical_imputer, numerical_features)],
     remainder='drop', n_jobs=-1)

# %%
train_X = missing_preprocessor.fit_transform(train_X)
train_X
# Out:
# array([[ 2. ,  1. ,  1. , ...,  1. , 10. ,  2. ],
#        [ 8. ,  2.5,  3. , ...,  1. ,  0. , 14. ],
#        [ 6. ,  3. ,  3. , ...,  1. ,  0. , 14. ],
#        ...,
#        [ 1. ,  1.5,  1. , ...,  1. ,  0. ,  1. ],
#        [ 2. ,  1. ,  1. , ...,  1. ,  0. ,  1. ],
#        [ 3. ,  2. ,  2. , ...,  1. ,  0. ,  2. ]])

# %%
train_X = pd.DataFrame(data=train_X, columns=used_features_new)
train_X
# Out:
#        accommodates  bathrooms  bedrooms  beds  square_feet  security_deposit  \
# 0               2.0        1.0       1.0   1.0        753.0             300.0
# 1               8.0        2.5       3.0   4.0       1400.0             771.0
# 2               6.0        3.0       3.0   3.0       1800.0             600.0
# 3               9.0        4.0       4.0   6.0       2100.0             300.0
# 4               8.0        3.0       4.0   6.0       2220.0            2505.0
# ...             ...        ...       ...   ...          ...               ...
# 51810           2.0        1.0       2.0   1.0        753.0             100.0
# 51811           6.0        2.0       2.0   2.0        753.0            3856.0
# 51812           1.0        1.5       1.0   1.0        753.0             100.0
# 51813           2.0        1.0       1.0   4.0        753.0             100.0
# 51814           3.0        2.0       2.0   1.0        753.0             100.0
#
#        cleaning_fee  guests_included  extra_people  minimum_nights
# 0              10.0              1.0          10.0             2.0
# 1              30.0              1.0           0.0            14.0
# 2              30.0              1.0           0.0            14.0
# 3             100.0              7.0         100.0            14.0
# 4             180.0              1.0           0.0            14.0
# ...             ...              ...           ...             ...
# 51810          30.0              1.0           0.0             2.0
# 51811          75.0              2.0          10.0             3.0
# 51812          30.0              1.0           0.0             1.0
# 51813          30.0              1.0           0.0             1.0
# 51814          30.0              1.0           0.0             2.0
#
# [51815 rows x 10 columns]

# %% [markdown]
# #### Logarithmic function transformer

# %%
log_scale_transformer = Pipeline(steps=[
    ('log_preprocessing', FunctionTransformer(log_preprocessing, inverse_log_preprocessing, validate=False)),
    ('log_transorm', FunctionTransformer(np.log, inverse_np_log, validate=False)),
    ('scaler', StandardScaler())
])

# %%
log_scale_price_transformer = Pipeline(steps=[
    ('log_preprocessing', FunctionTransformer(log_preprocessing, inverse_log_preprocessing, validate=False)),
    ('log_transorm', FunctionTransformer(np.log, inverse_np_log, validate=False)),
    ('scaler', StandardScaler())
])

# %%
log_scale_preprocessor = ColumnTransformer(transformers=[
    ('log_scale', log_scale_transformer, numerical_features)],
     remainder='drop', n_jobs=-1)

# %%
train_X = log_scale_preprocessor.fit_transform(train_X)

# %%
train_X_price = log_scale_price_transformer.fit_transform(train_X_price)

# %%
train_y = pd.DataFrame(data=train_X_price, columns=['price'])

# %%
train_X = pd.DataFrame(data=train_X, columns=used_features_new)

# %% [markdown]
# ## Model selection and cross-validation

# %%
scorer = make_scorer(mean_absolute_percentage_error, greater_is_better=False)

# %%
val_train_X, val_test_X, val_train_y, valid_test_y = train_test_split(train_X, train_y, test_size=0.2, random_state=RANDOM_STATE)

# %% [markdown]
# ## Prediction

# %%
test_X = missing_preprocessor.transform(test_X)
test_X
# Out:
# array([[ 2. ,  1. ,  1. , ...,  1. , 15. ,  1. ],
#        [ 2. ,  1. ,  1. , ...,  2. , 35. ,  2. ],
#        [ 2. ,  1. ,  1. , ...,  1. , 15. ,  1. ],
#        ...,
#        [ 6. ,  1.5,  3. , ...,  1. ,  0. ,  4. ],
#        [ 5. ,  1. ,  3. , ...,  1. ,  0. ,  2. ],
#        [ 2. ,  1. ,  1. , ...,  1. ,  0. ,  1. ]])

# %%
test_X = pd.DataFrame(data=test_X, columns=used_features_new)
test_X = log_scale_preprocessor.transform(test_X)
test_X = pd.DataFrame(data=test_X, columns=used_features_new)
test_X
# Out:
#        accommodates  bathrooms  bedrooms      beds  square_feet  \
# 0         -0.584410  -0.523183 -0.341796 -0.716333     0.007170
# 1         -0.584410  -0.523183 -0.341796 -0.716333     0.007170
# 2         -0.584410  -0.523183 -0.341796 -0.716333    -5.667409
# 3          1.414636   1.382496  1.640211  1.229452     0.007170
# 4          0.620791   0.525588  0.817604  0.421878     4.814260
# ...             ...        ...       ...       ...          ...
# 22995     -0.584410  -0.523183 -0.341796 -0.716333     0.007170
# 22996      0.094324  -0.523183 -0.341796  0.421878     0.007170
# 22997      1.414636   0.525588  1.640211  1.229452     0.007170
# 22998      1.050946  -0.523183  1.640211  1.229452     0.007170
# 22999     -0.584410  -0.523183 -0.341796 -0.716333     0.007170
#
#        security_deposit  cleaning_fee  guests_included  extra_people  \
# 0              0.339422     -1.077076        -0.513550      1.223568
# 1              0.339422      0.145329         0.681877      1.803300
# 2              0.339422     -0.451548        -0.513550      1.223568
# 3              0.904714      0.827278         2.187936      0.955701
# 4              0.752537      0.893180         0.681877      1.223568
# ...                 ...           ...              ...           ...
# 22995          1.066187      0.397639        -0.513550     -0.758546
# 22996          0.334907     -2.953660         0.681877     -0.758546
# 22997          0.210366      0.280273        -0.513550     -0.758546
# 22998          0.752537      0.397639        -0.513550     -0.758546
# 22999          0.339422     -1.336694        -0.513550     -0.758546
#
#        minimum_nights
# 0           -0.844451
# 1           -0.188691
# 2           -0.844451
# 3            0.276579
# 4            5.329952
# ...               ...
# 22995        0.276579
# 22996       -0.844451
# 22997        0.637470
# 22998       -0.188691
# 22999       -0.844451
#
# [23000 rows x 10 columns]

# %%
model = lgbm.sklearn.LGBMRegressor(learning_rate=0.95,
                                       n_estimators=25000,
                                       n_jobs=-1,
                                       subsample=0.5,
                                       colsample_bytree=0.65,
                                       reg_alpha=0.04,
                                       reg_lambda=0.28,
                                       objective="mape",
                                       random_state=42)

# %%
model.fit(train_X, train_y)
# Out:
# LGBMRegressor(colsample_bytree=0.65, learning_rate=0.95, n_estimators=25000,
#               objective='mape', random_state=42, reg_alpha=0.04,
#               reg_lambda=0.28, subsample=0.5)

# %%
pred = model.predict(train_X)

# %%
mean_absolute_percentage_error(train_y, pred)
# Out:
# 1.1500731634236019

# %%
prediction = model.predict(test_X)

# %%
prediction = log_scale_price_transformer.inverse_transform(prediction)

# %%
submission = pd.DataFrame(data=zip(test_data['id'], prediction), columns=['id', 'price'])

# %%
submission
# Out:
#              id       price
# 0          9554   47.754581
# 1         11076   59.680404
# 2         13913   49.661215
# 3         17402  124.391300
# 4         24328  137.827484
# ...         ...         ...
# 22995  13559787  103.810317
# 22996  13561162  209.215335
# 22997  13561394   79.292104
# 22998  13561787  153.164978
# 22999  13561861   39.217722
#
# [23000 rows x 2 columns]

# %%
submission
# Out:
#              id       price
# 0          9554   40.277229
# 1         11076   60.080887
# 2         13913   45.715095
# 3         17402  146.449236
# 4         24328   97.572770
# ...         ...         ...
# 22995  13559787  106.986834
# 22996  13561162  111.382336
# 22997  13561394  106.904207
# 22998  13561787  121.487876
# 22999  13561861   40.793844
#
# [23000 rows x 2 columns]

# %%
submission.to_csv("submission2.csv", index=False)

# %% [markdown]
# ## Experiments

# %% [markdown]
# #### Extract amenities and make them work

# %%
features = set()
amenities = pd.concat([train_data['amenities'], test_data['amenities']])
for i in range(len(amenities)):
    amenity_list = amenities.iloc[i].strip('{}').split(',')
    for feature in amenity_list:
        features.add(feature.strip('""'))

# %%
unnecesary_features = ['', 'Accessible-height bed', 'Accessible-height toilet',
                       'Alfresco bathtub', 'Amazon Echo', 'Baby bath', 'Baby monitor', 'Babysitter recommendations',
                       'Bathtub with bath chair', 'Beach essentials', 'Breakfast table', 'Cat(s)', 'Ceiling hoist',
                       'Changing table', 'Children’s books and toys', 'Children’s dinnerware', 'Cooking basics',
                       'Crib', 'DVD player', 'Day bed', 'Dog(s)', 'Double oven', 'Electric profiling bed', 'En suite bathroom',
                       'Espresso machine', 'Exercise equipment', 'Extra pillows and blankets', 'Fax machine',
                         'Fire extinguisher', 'Fire pit', 'Fireplace guards', 'Firm mattress', 'Fixed grab bars for shower',
                         'Fixed grab bars for toilet', 'Flat path to front door', 'Formal dining area', 'Free parking on premises',
                         'Free street parking', 'Gym', 'HBO GO', 'Hammock', 'Handheld shower head', 'Hangers', 'Heat lamps', 'Heated towel rack', 'High chair',
                         'High-resolution computer monitor', 'Host greets you', 'Jetted tub', 'Keypad', 'Kitchenette', 'Memory foam mattress', 'Mobile hoist',
                         'Mountain view', 'Mudroom', 'Murphy bed', 'Netflix', 'Other', 'Other pet(s)', 'Outdoor kitchen',
                         'Outdoor parking', 'Outdoor seating', 'Outlet covers', 'Oven', 'Pack ’n Play/travel crib', 'Paid parking off premises',
                         'Paid parking on premises', 'Patio or balcony', 'Pocket wifi', 'Pool with pool hoist', 'Printer', 'Private pool',
                         'Projector and screen', 'Rain shower', 'Shared gym', 'Shared pool', 'Shower chair', 'Single level home',
                         'Ski-in/Ski-out', 'Smart TV', 'Smart lock', 'Soaking tub', 'Window guards', 'Sound system', 'Stair gates',
                         'Stand alone steam shower', 'Standing valet', 'Steam oven', 'Step-free access', 'Stove', 'Tennis court', 'Touchless faucets',
                         'Walk-in shower', 'Warming drawer', 'Wide clearance to bed', 'Wide clearance to shower', 'Wide doorway',
                         'Wide entryway', 'Wide hallway clearance', 'translation missing: en.hosting_amenity_49',
                         'translation missing: en.hosting_amenity_50', 'Well-lit path to entrance',
                         'Wheelchair accessible', ' toilet', 'Air purifier', 'BBQ grill', 'Bathtub', 'Beach view', 'Beachfront',
                         'Bed linens', 'Bedroom comforts', 'Bidet', 'Body soap', 'Building staff', 'Buzzer/wireless intercom',
                         'Cable TV', 'Carbon monoxide detector', 'Ceiling fan', 'Coffee maker', 'Convection oven', 'Disabled parking spot',
                         'Dishes and silverware', 'Doorman', 'Dryer', 'EV charger', 'Essentials',
                         'Ethernet connection', 'Game console', 'Garden or backyard', 'Gas oven', 'Ground floor access',
                         'Hair dryer', 'Hot tub', 'Toilet paper', 'Washer', 'Wine cooler', 'Sun loungers', 'TV', 'Table corner guards',
                         'Terrace', 'Shampoo', 'Pool cover', 'Private bathroom', 'Private entrance', 'Private hot tub',
                         'Private living room', 'Mini fridge', 'Pets allowed', 'Pets live on this property',
                         'Pillow-top mattress', 'Lockbox', 'Long term stays allowed', 'Luggage dropoff allowed', 'Bath towel',
                         'Bathroom essentials', 'Dining table', 'Dishwasher', 'Elevator', 'Hot water', 'Hot water kettle', 'Indoor fireplace', 'Laptop friendly workspace',
                         'Lock on bedroom door', 'Roll-in shower', 'Room-darkening shades', 'Safety card',
                         'Self check-in', 'Waterfront',]

# %%
for un_feature in unnecesary_features:
    features.remove(un_feature)

# %%
features

# %%
train_data['neighbourhood_cleansed'].value_counts()
